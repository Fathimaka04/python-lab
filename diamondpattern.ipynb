# %% [markdown]
# Construct following pattern using nested loop

# %%
n=int(input("enter the limit:"))
for i in range(1,n+1): #upper triangle
  for j in range(1,i+1):
    print("*",end=" ")
  print()
for i in range(n-1,0,-1): #lower triangle
  for j in range(1,i+1):
    print("*",end=" ")
  print()
# Out:
# enter the limit:5
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * *
# * * *
# * *
# *
