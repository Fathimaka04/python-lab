# %% [markdown]
# Aim: to find the biggest of 3 numbers entered

# %%
import math
r=int(input("enter the radius"))
area=math.pi*r*r
print("area of the circle :", round(area,2))
# Out:
# enter the radius 6
# area of the circle : 113.1
