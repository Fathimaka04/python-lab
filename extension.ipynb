# %% [markdown]
# Aim: accept a file namefrom user and print extension of that

# %%
file=input("enter the name:")
temp=file.split(".")
ext=temp[-1] if len(temp)>1 else ""
print("extension:",ext)
# Out:
# enter the name:python.pdf
# extension: pdf
