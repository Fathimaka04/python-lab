# %% [markdown]
# Aim:count the occurences of each word in a line of text

# %%
l=input(" enter a line:")
words=l.split()
res={}
for words in words:
  words=words.lower()
  if words in res:
    res[words]+=1
  else:
    res[words]=1
for words,count in res.items():
  print(words,":",count)
# Out:
#  enter a line:believe you can and you are halfway there
# believe : 1
# you : 2
# can : 1
# and : 1
# are : 1
# halfway : 1
# there : 1
