# %% [markdown]
# Aim:  to create a string from given string where first  and last characters exchanged

# %%
s=input("enter a string:")
f=s[0]
l=s[-1]
print("new string:",l+s[1:-1]+f)
# Out:
# enter a string:fathima
# new string aathimf
