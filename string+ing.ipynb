# %% [markdown]
# Add ‘ing’ at the end of a given string. If it already ends with ‘ing’, then add ‘ly’

# %%
s=input("enter a string")
a=s[-3:] #take the last 3 characters of the string
if a=="ing":
  print(s+"ly")
else:
  print(s+"ing")
# Out:
# enter a string hello
#  helloing
