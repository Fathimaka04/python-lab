# %% [markdown]
# Sort dictionary in ascending and descending order

# %%
d={
    "apple":3,
    "banana":1,
    "cherry":5,
    "date":5,
    "blueberry":4
}
print("ascending order:",dict(sorted(d.items())))
print("descending order:",dict(sorted(d.items(),reverse=True)))
# Out:
# ascending order: {'apple': 3, 'banana': 1, 'blueberry': 4, 'cherry': 5, 'date': 5}
# descending order: {'date': 5, 'cherry': 5, 'blueberry': 4, 'banana': 1, 'apple': 3}
