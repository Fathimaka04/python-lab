# %% [markdown]
# Generate all factors of a number

# %%
def factors(a):
  for i in range(1,a+1):
    if a%i==0:
      print(i)

abs=int(input("enter a input:"))
factors(a)
# Out:
# enter a input:678
# 1
# 2
# 3
# 6
# 113
# 226
# 339
# 678
