# %% [markdown]
# Accept a list of words and return length of longest word

# %%
s=[i for i in input("enter some words:").split()]
print(len(max(s,key=len)))
# Out:
# enter some words: banana cherry apple
# 6
