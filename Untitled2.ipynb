# %% [markdown]
# create a class time with private attributes hour,minute and second.overload'+' operator to find sum of 2 times

# %%
class Time:
  def __init__(self,__hr,__min,__sec):
    self.__hr=__hr
    self.__min=__min
    self.__sec=__sec
    self.normalize()

  def normalize(self):
    if self.__sec>=60:
      self.__min+=self.__sec//60
      self.__sec=self.__sec%60
    if self.__min>=60:
      self.__hr+=self.__min//60
      self.__min+=self.__min%60
  #adding time
  def __add__(self,obj2):
    n_hr=self.__hr+ obj2.__hr
    n_min=self.__min+obj2.__sec
    n_sec=self.__sec+obj2.__sec
    return Time(n_hr,n_min,n_sec)
  def __str__(self):
    return f"{self.__hr:02}:{self.__min:02}:{self.__sec:02}"
hr=int(input("enter hour:"))
mint=int(input("enter minute:"))
sec=int(input("enter the sec"))
t1=Time(hr,mint,sec)
print(Time,":",hr,":",mint,":",sec,"\n")
print()
hr1=int(input("enter Hour:"))
mint1=int(input("enter the minute:"))
sec1=int(input("enter second:"))
t2=Time(hr1,mint1,sec1)
print(":",hr1,":",mint1,":",sec1,"\n")
print()

#calling add
t3=t1+t2
print("sum of the time",t3)
# Out:
# enter hour:5
# enter minute:44
# enter the sec22
# <class '__main__.Time'> : 5 : 44 : 22
#
#
# enter Hour:4
# enter the minute:55
# enter second:23
# : 4 : 55 : 23
#
#
# sum of the time 10:74:45
