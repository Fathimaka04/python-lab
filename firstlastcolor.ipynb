# %% [markdown]
# Aim:Create a list of colors from comma-separated color names entered by user. Display
# first and last colors.

# %%
c=input("enter colors:")
colors=[i.strip() for i in c.split(",")] #strip() removes any extra spaces at the beginning or end of the string.
print("first color:",colors[0],"\nlast color",colors[-1])
# Out:
# enter colors:red , blue ,green,yellow
# first color: red
# last color yellow
