# %% [markdown]
# Form a list of integers,create a list removing even numbers.

# %%
oldlist=[int(i) for i in input("enter the numbers:").split()]
newlist=[i for i in oldlist if i%2!=0]
print("list after removing even numbers:",newlist)
# Out:
# enter the numbers: 13 45 22 24 67 98 99 6
# list after removing even numbers: [13, 45, 67, 99]
