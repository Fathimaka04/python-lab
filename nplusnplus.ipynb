# %% [markdown]
# Aim:Accept an integer n and compute n+nn+nnn.

# %%
x=int(input('enter a integer:'))
n1= int(f"{x}") #n
n2=int(f"{x}{x}")#nn
n3=int(f"{x}{x}{x}")#nnn
print(n1,"+",n2,"+",n3)
# Out:
# enter a integer:4
# 4 + 44 + 444
