# %% [markdown]
# Merge two dictionaries.

# %%
d={

   "name":"Fathima",
   "age":21,
   "place":"Ernakulam"
}

c={
    "course":"MCA",
    "year": 2025
}

m=d|c  #| merge operator
print("merged dictionary",m)
# Out:
# merged dictionary {'name': 'Fathima', 'age': 21, 'place': 'Ernakulam', 'course': 'MCA', 'year': 2025}
