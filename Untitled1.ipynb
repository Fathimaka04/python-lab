# %% [markdown]
# Find the sum of all items in a list.

# %%
li=[int(i) for i in input("enter the list:").split()]
newlist=sum(li)
print("sum of the list is:",newlist)
# Out:
# enter the list:1 2 3
# sum of the list is: 6
