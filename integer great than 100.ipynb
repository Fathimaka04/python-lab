# %% [markdown]
# Aim:prompt the user  for a list of integers.For all values greater than 100,store 'over' instead.

# %%
# !git clone https://github.com/Fathimaka04/python-lab.git
# Out:
# Cloning into 'python-lab'...
# remote: Enumerating objects: 13, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 13 (delta 1), reused 9 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (13/13), 320.16 KiB | 13.34 MiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %%
# !cp /content/*.ipynb /content/python-lab/
# Out:
# cp: cannot stat '/content/*.ipynb': No such file or directory

# %%
# !ls /content
# Out:
# python-lab  sample_data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive
# Out:
# '10 mark list.pdf'
#  16316321612863444868676081155838.jpg
# '+2 marklist.pdf'
#  5437706_9374.pdf
# 'adhaar .pdf'
# 'birth certificate.pdf'
# 'CC page 2.pdf'
# 'CC page 3.pdf'
#  Classroom
# 'Colab Notebooks'
# 'consolidated mark cum grade card.pdf'
# 'Edited - Scanned_20210602-0951.pdf'
# 'Google Keep Document.gdoc'
# 'hall ticket.pdf'
# 'How simple'
#  IMG20210914203209.jpg
#  IMG20210914203211.jpg
#  IMG20220222072323.jpg
#  maths.pdf
#  nativity.pdf
# 'non creamy .pdf'
# 'Page 1.pdf'
# 'passport size.jpg'
# 'passport sizepic.pdf'
#  pic.pdf
# 'provisional certificate.pdf'
# 'Read it on Pratilipi - "ഇച്ചായൻ്റെ ഊമകൊച്ച്❤️"'
#  record
#  Scanned_20210614-1940.pdf
# 'Signature .jpg'
# 'test cases.gsheet'
# 'Untitled folder'
# 'Untitled spreadsheet.gsheet'

# %%
# !ls /content/drive/MyDrive/Colab\ Notebooks
# Out:
#  bank.ipynb			 leapyaer.ipynb
#  biggestof.ipynb		 lengthandsum.ipynb
#  characterfreq.ipynb		 listcomprehension.ipynb
#  circlearea.ipynb		 listsquare.ipynb
#  circleare.ipynb		'longestword .ipynb'
#  diamondpattern.ipynb		 notevenlist.ipynb
#  dicmerge.ipynb			 nplusnplus.ipynb
#  dictascendingdescending.ipynb	 occurenceofa.ipynb
#  evensquare.ipynb		 occurenceofwrod.ipynb
#  extension.ipynb		 occurrenceoffirstchar.ipynb
#  factorial.ipynb		 pyramid.ipynb
#  factors.ipynb			 rectangleclass.ipynb
#  fibonacci.ipynb		 string+ing.ipynb
#  firstandlastchange.ipynb	 sumlist.ipynb
#  firstandlastcoloroutput.ipynb	 swap1and2.ipynb
#  firstlastcolor.ipynb		 Untitled0.ipynb
#  gcd.ipynb			 Untitled1.ipynb
# 'integer great than 100.ipynb'	 Untitled2.ipynb
#  lambdafunction.ipynb		 Untitled5.ipynb

# %%
l=[int(i) for i in input("enter list:").split()]
new=["over" if i>100 else i for i in l]
print("new list :",new)
# Out:
# enter list: 45 200 4 500 3 67 100 678 8 4
# new list : [45, 'over', 4, 'over', 3, 67, 100, 'over', 8, 4]
