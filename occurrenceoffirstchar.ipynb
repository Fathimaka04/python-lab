# %% [markdown]
# Aim :to get a string from an input string where all occurrences of first charactefr replaced with '$' except  first character

# %%
l=input("enter a string: ")
f=l[0]
l1=l[1:].replace(f,'$')
print("new string:",f+l1)
# Out:
# enter a string: adhithya
# new string: adhithy$
