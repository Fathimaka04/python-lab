# %% [markdown]
# Aim:store a list of first names.count the occurrences of 'a' within the list.

# %%
l=[i for i in input("enter list:").split()]
count=0
for i in l:
  count+=i.lower().count("a")
print("count of letter A:",count)
# Out:
# enter list: raaniya minha fathima nazrin
# count of letter A: 7
