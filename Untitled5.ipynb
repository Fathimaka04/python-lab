# %% [markdown]
# Aim:Print out all colors from color-list1 not contained in color-list2.

# %%
l1=[i for i in input("enter the list1").split()]
l2=[i for i in input("enter the list2").split()]
r=[i for i in l1 if i not in l2]
print("result",r)
# Out:
# enter the list1 red green yellow violet
# enter the list2 green black blue
# result ['red', 'yellow', 'violet']
